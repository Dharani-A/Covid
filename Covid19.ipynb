# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import ast
import json

# %% [markdown]
# # Test the locally saved json file

# %%
with open('answers.json', encoding="utf-8") as json_file:
    data = json.load(json_file)

# %%
type(data)
# Out:
# list

# %%
for ids in data:
    print(ids["_id"])
type(ids)
# Out:
# {'$oid': '5e95e813adc973d6c9ccda09'}
# {'$oid': '5e95eda2adc973d6c9ccda0a'}
# {'$oid': '5e95ee5dadc973d6c9ccda0b'}
# {'$oid': '5e960740adc973d6c9ccda0c'}
# {'$oid': '5e961c6badc973d6c9ccda0d'}
# {'$oid': '5e963e03adc973d6c9ccda0e'}
# {'$oid': '5e96a642adc973d6c9ccda0f'}
# {'$oid': '5e96a64badc973d6c9ccda10'}
# {'$oid': '5e96e524adc973d6c9ccda11'}
# {'$oid': '5e96f0baadc973d6c9ccda12'}
# {'$oid': '5e96f0d3adc973d6c9ccda13'}
# {'$oid': '5e96f251adc973d6c9ccda14'}
# {'$oid': '5e96f6f3adc973d6c9ccda15'}
# {'$oid': '5e96f994adc973d6c9ccda16'}
# {'$oid': '5e96fa5cadc973d6c9ccda17'}
# {'$oid': '5e96faacadc973d6c9ccda18'}
# {'$oid': '5e96fbd3adc973d6c9ccda19'}
# {'$oid': '5e96fc71adc973d6c9ccda1a'}
# {'$oid': '5e96fd1dadc973d6c9ccda1b'}
# {'$oid': '5e96fd97adc973d6c9ccda1c'}
# {'$oid': '5e96fe5aadc973d6c9ccda1d'}
# {'$oid': '5e96ff4fadc973d6c9ccda1e'}
# {'$oid': '5e96fffcadc973d6c9ccda1f'}
# {'$oid': '5e970079adc973d6c9ccda20'}
# {'$oid': '5e975f13adc973d6c9ccda21'}
# ...

# %%
a = []
for ans in data:
    #print(ans)
    ans=ans
for p in ans["answer"]:
    a.append(p)
print(a)
# Out:
# ['{', '"', 'g', 'e', 'n', 'd', 'e', 'r', '"', ':', '"', 'U', 'o', 'm', 'o', '"', ',', '"', 'a', 'g', 'e', '"', ':', '"', '6', '0', '-', '6', '9', '"', ',', '"', 'p', 'o', 's', 'i', 't', 'i', 'v', 'e', '"', ':', '"', 'N', 'o', '"', ',', '"', 'f', 'e', 'v', 'e', 'r', '"', ':', '"', 'N', 'o', '"', ',', '"', 'c', 'o', 'u', 'g', 'h', '"', ':', '"', 'N', 'o', '"', ',', '"', 's', 'y', 'm', 'p', 't', 'o', 'm', 's', '"', ':', '[', '"', 'N', 'e', 's', 's', 'u', 'n', 'o', ' ', 'd', 'i', ' ', 'q', 'u', 'e', 's', 't', 'i', '"', ']', ',', '"', 'd', 'i', 'a', 'g', 'n', 'o', 's', 'e', 'd', '"', ':', '[', '"', 'N', 'e', 's', 's', 'u', 'n', 'a', '"', ']', ',', '"', 's', 'm', 'o', 'k', 'e', '"', ':', '"', 'N', 'o', '"', ',', '"', 'r', 'e', 'c', 'o', 'r', 'd', 'C', 'o', 'u', 'g', 'h', '"', ':', '"', '2', '0', '2', '0', '-', '0', '4', '-', '1', '6', 'T', '1', '0', ':', '1', '1', ':', '4', '8', '.', '4', '6', '5', 'Z', '7', 'U', 'Q', '5', 'n', 'f', '4', 'J', 'J', 'B', '.', 'w', 'a', 'v', '"', ',', '"', 'r
# ...

# %% [markdown]
# # Test locally saved csv file

# %%
data = pd.read_csv("dict_file.csv")
data
# Out:
#                                      _id  \
# 0   {'$oid': '5e95e813adc973d6c9ccda09'}
# 1   {'$oid': '5e95eda2adc973d6c9ccda0a'}
# 2   {'$oid': '5e95ee5dadc973d6c9ccda0b'}
# 3   {'$oid': '5e960740adc973d6c9ccda0c'}
# 4   {'$oid': '5e961c6badc973d6c9ccda0d'}
# 5   {'$oid': '5e963e03adc973d6c9ccda0e'}
# 6   {'$oid': '5e96a642adc973d6c9ccda0f'}
# 7   {'$oid': '5e96a64badc973d6c9ccda10'}
# 8   {'$oid': '5e96e524adc973d6c9ccda11'}
# 9   {'$oid': '5e96f0baadc973d6c9ccda12'}
# 10  {'$oid': '5e96f0d3adc973d6c9ccda13'}
# 11  {'$oid': '5e96f251adc973d6c9ccda14'}
# 12  {'$oid': '5e96f6f3adc973d6c9ccda15'}
# 13  {'$oid': '5e96f994adc973d6c9ccda16'}
# 14  {'$oid': '5e96fa5cadc973d6c9ccda17'}
# 15  {'$oid': '5e96faacadc973d6c9ccda18'}
# 16  {'$oid': '5e96fbd3adc973d6c9ccda19'}
# 17  {'$oid': '5e96fc71adc973d6c9ccda1a'}
# 18  {'$oid': '5e96fd1dadc973d6c9ccda1b'}
# 19  {'$oid': '5e96fd97adc973d6c9ccda1c'}
# 20  {'$oid': '5e96fe5aadc973d6c9ccda1d'}
# 21  {'$oid': '5e96ff4fadc973d6c9ccda1e'}
# ...

# %% [markdown]
# # Create json file for nepali language

# %%
covid_nep = [{'type': 'description',
  'question': 'खोकि विरुद्ध कोभिड १९',
  'handler': 'description',
  'options': ['अनुसन्धानले सुझाव दिन्छ कि खोकिको आवाजको ध्वनिक गुणहरूले बिरामीको अवस्थाको बारेमा उपयोगी जानकारी प्रदान गर्न सक्छ। हामी कोविड १९  महामारीको भाइरस लागेको बिरामी  र  नलनगेको  व्यक्तिहरुबाट खोकीको ध्वनीको कुनै विशेष विशेषताहरु छन् कि भनेर हेर्न र सो खोकीको डेटाबेस निर्माण गर्दैछौं। के तपाई कोविड १९  महामारीबिरूद्ध लड्न र दान गर्न इच्छुक हुनु हुन्छ.',
   'यो अनुसन्धान मानवताको हितको लागि वैज्ञानिक प्रगतिहरुको योगदानको रूपमा गैर नाफामृलक संस्था Yoursciencebc Ltd द्वारा प्रायोजित भएको  छ। कुनै पनी व्यक्तिगत डेटा  लाई रेर्कड गरिने छैन् ।'],
  'validation': 'required'},
 {'type': 'dropdown',
  'question': 'तपाईको लिङ्ग के हो ?',
  'handler': 'लिङ्',
  'options': ['पुरुष', 'महिला', 'अरु', 'भन्न चाहँदीन'],
  'validation': 'required'},
 {'type': 'dropdown',
  'question': 'तपाईको उमेर दायरा के हो?',
  'handler': 'उमेर',
  'options': ['दस बर्ष मुनी',
   '१०–१९',
   '२०–२९',
   '३०–३९',
   '४०–४९ ',
   '५०–५९',
   '६०–६९',
   '७०-७९',
   '८० भन्दा माथी',
   'कुनै जानकारी नदीने'],
  'validation': 'required'},
 {'type': 'dropdown',
  'question': 'तपाईलाई  गएको  २ हप्तामा कोविड १९  महामारीको भाइरस को लागी परिक्षण गरिएको छ ? यदी गरिएको छ भने तपाईंको परिक्षणको नतिजा के हो ?',
  'handler': 'पोजेटीभ',
  'options': ['छ,पोजेटीभ', 'छ, नेगेटिभ', 'छैन्'],
  'validation': 'required'},
 {'type': 'dropdown',
  'question': 'तपाईलाई ज्वरो आएको छ?',
  'handler': 'ज्वरो',
  'options': ['छ ३९ * सि(१०२* फ) भन्दा बढी',
   'छ ३७.५* सि (९९.५* फ) भन्दा बढी',
   'छैन'],
  'validation': 'required'},
 {'type': 'dropdown',
  'question': 'तपाईलाई खोकी छ?',
  'handler': ' खोकी',
  'options': ['छ', 'छैन'],
  'validation': 'required'},
 {'type': 'checkbox',
  'question': 'के तपाईंलाई यी लक्षणहरूमध्ये कुनै छ ?(लागू हुने सबै चयन गर्नुहोस्)',
  'handler': 'लक्षणहरू',
  'options': ['सासको कमी',
   'टाउको दुखाई',
   'शरीर दुखाइ र पीडा',
   'दुखेको घाँटी',
   'थकान',
   'पखाला',
   'नाक बाट पानी बग्नु',
   'स्वादको अभाव',
   'छींक आयो',
   'यी मध्ये कुनै पनि होईन'],
  'validation': 'required'},
 {'type': 'checkbox',
  'question': 'तपाईसँग हाल श्वासप्रश्वाससम्बन्धी कुनै रोग लागेको छ ?(कृपया लागू हुने सबै चयन गर्नुहोस्)',
  'handler': 'निदान',
  'options': [
   'दम',
   'ब्रोंकाइटिस',
   'दीर्घकालीन अवरोधक फुफ्फुसीय रोग',
   'खण्डन',
   'निमोनिया',
   'अन्य',
  'कुनै पनि होईन'],
  'validation': 'required'},
 {'type': 'dropdown',
  'question': 'तपाई धुम्रपान गर्नुहुन्छ?',
  'handler': 'धुम्रपान',
  'options': ['छ', 'छैन'],
  'validation': 'required'},
 {'type': 'recording',
  'question': 'अब तपाईको खोकी रेकर्ड गर्ने समय आएको छ। तपाईको खोकी  रेकर्ड तीन छुट्टै चोटी गर्नुहोस् सो खोकिको प्रत्येक रेकर्डि  १० सेकेन्डको सीमा हुनेछ।   जति धैरै तपाईको खोकी रेकर्ड डाटा हामीसँग हुनेछ त्यति  राम्रो हुनेछ.*',
  'handler': 'खोकी रेकर्ड ',
  'options': [],
  'validation': 'required'},
 {'type': 'recording',
  'question': 'हामीलाई तपाईंको आवाजको पृष्ठभूमि पढ्नको लागि कृपया १ देखि २० सम्म गणना गर्दै रेकर्ड गर्नुहोस्।',
  'handler': 'आवाज रेकर्ड गर्नुहोस्',
  'options': [],
  'validation': 'required'}]

# %%
with open('NepaliQuestionList.json', 'w') as json_file:
    json.dump(covid_nep, json_file)

# %%
with open('NepaliQuestionList.json.', encoding="utf-8") as json_file:
    data = json.load(json_file)

# %% [markdown]
# # Make connection to mongodb database

# %%
import pymongo

# %%
from pymongo import MongoClient

client = MongoClient('mongodb://root:7Y6kYGZ6ZABKxFgAZagg@covid-record.com:27017/covid-record?authSource=admin')

db = client['covid-record']

print(db.list_collection_names())
# Out:
# ['SimplifiedChinese', 'zh', 'fr', 'Italian', 'it', 'French', 'English', 'en', 'sr', 'nl']

# %%
#python - DAtabase exists check
print(client.list_database_names())
# Out:
# ['admin', 'config', 'covid-record', 'local']

# %%
print(db.list_collection_names())
# Out:
# ['SimplifiedChinese', 'zh', 'fr', 'Italian', 'it', 'French', 'English', 'en', 'sr', 'nl']

# %%
#EXtracting data from collection 'en'
colen = db["en"]
#Function to find and print the first record from the document
fcolen = colen.find_one()
#print(fcolen)
for fcolen in colen.find():
    print(fcolen)
# Out:
# {'_id': '608bf5f9-bad5-45e2-adf2-759ae192ba25', 'recordCough': ['608bf5f9-bad5-45e2-adf2-759ae192ba25_20200424_133937541.wav', '608bf5f9-bad5-45e2-adf2-759ae192ba25_20200424_133955628.wav', '608bf5f9-bad5-45e2-adf2-759ae192ba25_20200424_134005699.wav'], 'recordVoice': ['608bf5f9-bad5-45e2-adf2-759ae192ba25_20200424_134049147.wav', '608bf5f9-bad5-45e2-adf2-759ae192ba25_20200424_134112887.wav'], 'smoke': 'No', 'diagnosed': ['None'], 'symptoms': ['Sneezing', 'Runny nose'], 'cough': 'No', 'fever': 'No', 'positive': 'No', 'age': '20-29', 'gender': 'Female', 'datetime': datetime.datetime(2020, 4, 24, 11, 41, 13, 889000)}
# ...

# %%
#Extracting data from Collection 'English'
colEnglish = db['English']
for alldocEnglish in colEnglish.find():
    print(alldocEnglish)
#Print count of collection
print(colEnglish.estimated_document_count())
#Print type of the variable
print(type(alldocEnglish))
#Print the key value in the dictionary
print(alldocEnglish.keys())
#Print the key values as a list instead of dict_keys
print(list(alldocEnglish))
# Out:
# {'_id': '81b2beff-5322-4fd4-b44b-2aea61930188', 'recordCough': ['81b2beff-5322-4fd4-b44b-2aea61930188_20200421_133730866.wav', '81b2beff-5322-4fd4-b44b-2aea61930188_20200421_133736780.wav', '81b2beff-5322-4fd4-b44b-2aea61930188_20200421_133741747.wav'], 'recordVoice': ['81b2beff-5322-4fd4-b44b-2aea61930188_20200421_133811219.wav'], 'gender': 'Male', 'age': '40-49', 'positive': 'No', 'fever': 'No', 'cough': 'No', 'symptoms': [], 'diagnosed': ['None'], 'smoke': 'No', 'datetime': datetime.datetime(2020, 4, 21, 17, 38, 32, 572000)}
# ...

# %%
column_names = list(alldocEnglish)
print(column_names)
good_columns = ['_id', 'recordCough', 'recordVoice', 'gender', 'age', 'positive', 'fever', 'cough', 'symptoms', 'diagnosed', 'smoke', 'datetime']
#print(good_columns)
data = []
objects = list(alldocEnglish.values())
#print(objects)
for row in objects:
    print(row)
    selected_row = []
    for item in good_columns:
        print(item)
#import pandas as pd
#df = pd.DataFrame(data)
#print(df)
# Out:
# ['_id', 'recordCough', 'recordVoice', 'gender', 'age', 'positive', 'fever', 'cough', 'symptoms', 'diagnosed', 'smoke', 'datetime']
# 8aed5f39-569d-4560-9491-73732a27dbac
# _id
# recordCough
# recordVoice
# gender
# age
# positive
# fever
# cough
# symptoms
# diagnosed
# smoke
# datetime
# ['8aed5f39-569d-4560-9491-73732a27dbac_20200423_183700414.wav', '8aed5f39-569d-4560-9491-73732a27dbac_20200423_183715852.wav', '8aed5f39-569d-4560-9491-73732a27dbac_20200423_183729526.wav']
# _id
# recordCough
# recordVoice
# gender
# age
# positive
# fever
# cough
# symptoms
# diagnosed
# smoke
# datetime
# ['8aed5f39-569d-4560-9491-73732a27dbac_20200423_183755614.wav', '8aed5f39-569d-4560-9491-73732a27dbac_20200423_183824717.wav', '8aed5f39-569d-4560-9491-73732a27dbac_20200423_183847794.wav']
# _id
# recordCough
# recordVoice
# gender
# age
# positive
# fever
# cough
# symptoms
# diagnosed
# smoke
# datetime
# Male
# _id
# recordCough
# recordVoice
# gender
# age
# positive
# fever
# cough
# ...

# %%
#import pandas as pd
#df = pd.DataFrame.from_dict(alldocEnglish, orient='index')
#df.head()
import pandas as pd
df = pd.DataFrame.from_records(db.'covid-record')
print(df)
# Out:
#   File "<ipython-input-51-ef7de4274907>", line 5
#     df = pd.DataFrame.from_records(db.'covid-record')
#                                                    ^
# SyntaxError: invalid syntax

# %%
for findalldoc in col.find({},{"_id":1, "positive": 1 }):
    print(findalldoc)
# Out:
# {'_id': '608bf5f9-bad5-45e2-adf2-759ae192ba25', 'positive': 'No'}
# {'_id': '8d937ecf-d4b9-4902-b0ba-ad691e53b637', 'positive': 'No'}
# {'_id': '988e4af0-fcea-4236-bbac-1c07b8bf03f5', 'positive': 'No'}
# {'_id': 'f42194ad-09f6-4bf6-892a-76f9bf7cde36', 'positive': 'No'}
# {'_id': '16011f7f-f28e-442d-95c5-d5b5d88ab594', 'positive': 'No'}
# {'_id': '9c82c3d8-83a2-43e2-a552-30e57b378d4d', 'positive': 'No'}
# {'_id': '4847b8a8-66de-469d-a8e9-141a5bfe343d', 'positive': 'Yes, positive'}
# {'_id': '8553b697-0699-4f1d-b9c0-514e3b765304', 'positive': 'No'}

# %%
#Record voice
for findallrec in col.find({},{"_id":1, "recordVoice": 1 }):
    print(findallrec)
# Out:
# {'_id': '608bf5f9-bad5-45e2-adf2-759ae192ba25', 'recordVoice': ['608bf5f9-bad5-45e2-adf2-759ae192ba25_20200424_134049147.wav', '608bf5f9-bad5-45e2-adf2-759ae192ba25_20200424_134112887.wav']}
# {'_id': '8d937ecf-d4b9-4902-b0ba-ad691e53b637', 'recordVoice': ['8d937ecf-d4b9-4902-b0ba-ad691e53b637_20200424_203706394.wav']}
# {'_id': '988e4af0-fcea-4236-bbac-1c07b8bf03f5', 'recordVoice': ['988e4af0-fcea-4236-bbac-1c07b8bf03f5_20200424_223431810.wav']}
# {'_id': 'f42194ad-09f6-4bf6-892a-76f9bf7cde36', 'recordVoice': ['f42194ad-09f6-4bf6-892a-76f9bf7cde36_20200425_161455983.wav', 'f42194ad-09f6-4bf6-892a-76f9bf7cde36_20200425_161600436.wav', 'f42194ad-09f6-4bf6-892a-76f9bf7cde36_20200425_161742757.wav']}
# {'_id': '16011f7f-f28e-442d-95c5-d5b5d88ab594', 'recordVoice': ['_20200426_205310677.wav']}
# {'_id': '9c82c3d8-83a2-43e2-a552-30e57b378d4d', 'recordVoice': []}
# {'_id': '4847b8a8-66de-469d-a8e9-141a5bfe343d', 'recordVoice': ['_20200427_22475376.wav']}
# ...

# %%
import pydub

# %%
from pydub import AudioSegment
from pydub.playback import play

# %%
#download audio file
voice = findallrec['recordVoice']
voicerec = voice[0]
print(voicerec)
#loop = AudioSegment.from_wav("_20200427_22472948.wav")
#from pydub import AudioSegment
#audio_file = AudioSegment.from_wav('_20200427_22472948.wav')
# Out:
# <class 'str'>

# %%
import wave

# %%
obj = wave.open('/home/dhanabalan/Desktop/file_example_WAV_1MG.wav','r')
print( "Number of channels",obj.getnchannels())
print ( "Sample width",obj.getsampwidth())
obj.close()
# Out:
# Number of channels 2
# Sample width 2

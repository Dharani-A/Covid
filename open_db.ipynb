# %% [markdown]
# ### Import libraries ###

# %%
import pandas as pd
import ast
import json
import pymongo
import IPython

# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://root:7Y6kYGZ6ZABKxFgAZagg@covid-record.com:27017/covid-record?authSource=admin')

db = client['covid-record']

print(db.list_collection_names())
# Out:
# ['SimplifiedChinese', 'zh', 'fr', 'Italian', 'it', 'French', 'English', 'en', 'sr', 'nl']

# %%
#python - DAtabase exists check
print(client.list_database_names())
# Out:
# ['admin', 'config', 'covid-record', 'local']

# %%
db_local=client['local']
print(db_local.list_collection_names())
# Out:
# ['startup_log']

# %%
collection_startup_log=db_local.startup_log
df_collection_startup_log=pd.DataFrame(list(collection_startup_log.find()))

# %%
df_collection_startup_log
# Out:
#                            _id  \
# 0   ee6a53f445af-1587489558849
# 1   ee6a53f445af-1587489561798
# 2   ee6a53f445af-1587492270007
# 3   a701eed2d4bd-1587508976724
# 4   31e0e445ad10-1587548400410
# 5   070d2cea4ca5-1587590169866
# 6   8aa9ab1a3bbb-1587630328022
# 7   f9d901b49cf0-1587633233924
# 8   604be2ebf150-1587652790025
# 9   24d8bb6f8dd5-1587655561786
# 10  9edae66bf1ef-1587673075755
# 11  f4cea8fc928b-1587674277535
# 12  49ece20f0982-1587674416083
# 13  9c2a5f4cb980-1587674722969
# 14  8a52c41f6152-1587675360975
# 15  0fed9b6609a3-1587676244891
# 16  9cf85f8ccfa4-1587678119051
# 17  689fcb437a5f-1587718806820
# 18  e5b52d842d38-1587722636033
# 19  ff856fb14536-1587724360226
# 20  ccdef6e947a1-1587724585683
# 21  f8e1724c006b-1587724909166
# 22  c298bae990e4-1587725450840
# 23  a27aae403517-1587725822288
# 24  7773e2039587-1587726162601
# 25  4f4b020bdc9e-1587743143689
# 26  8a5ec891869b-1587745084091
# 27  d8b442b72079-1587746935378
# 28  fda0c1dd1dac-1587826000296
# ...

# %%
#collection_SimplifiedChinese= db[db.list_collection_names()[0]]
collection_SimplifiedChinese= db.SimplifiedChinese
df_SimplifiedChinese=pd.DataFrame(list(collection_SimplifiedChinese.find()))
print('SimplifiedChinese:',df_SimplifiedChinese.shape)

collection_zh=db.zh
df_zh=pd.DataFrame(list(collection_zh.find()))
print('zh:',df_zh.shape)

collection_fr=db.fr
df_fr=pd.DataFrame(list(collection_fr.find()))
print('fr:',df_fr.shape)

collection_Italian=db.Italian
df_Italian=pd.DataFrame(list(collection_Italian.find()))
print('Italian:',df_Italian.shape)

collection_it=db.it
df_it=pd.DataFrame(list(collection_it.find()))
print('it:',df_it.shape)

collection_French=db.French
df_French=pd.DataFrame(list(collection_French.find()))
print('French:',df_French.shape)

collection_English=db.English
df_English=pd.DataFrame(list(collection_English.find()))
print('English:',df_English.shape)

collection_en=db.en
df_en=pd.DataFrame(list(collection_en.find()))
print('en:',df_en.shape)

collection_sr=db.sr
df_sr=pd.DataFrame(list(collection_sr.find()))
print('sr:',df_sr.shape)

collection_nl=db.nl
df_nl=pd.DataFrame(list(collection_nl.find()))
print('nl:',df_nl.shape)

#print(collection.find_one())
#df
#i = 0
#while i < len(db.list_collection_names()):
#    collec=db[db.list_collection_names()[i]]
#    print(collec.count_documents({}))
    #collection_tot=db[db.list_collection_names()[i]]
#collection_tot.count_documents({})
#print("total_entries:" %d % ( eng_col.count_documents({})))
#print(eng_col.find_one())
# Out:
# SimplifiedChinese: (2, 12)
# zh: (1, 12)
# fr: (6, 12)
# Italian: (5, 12)
# it: (25, 14)
# French: (3, 12)
# English: (5, 12)
# en: (13, 13)
# sr: (3, 12)
# nl: (1, 12)

# %%
df_en
# Out:
#                                      _id    age cough                datetime  \
# 0   608bf5f9-bad5-45e2-adf2-759ae192ba25  20-29    No 2020-04-24 11:41:13.889
# 1   8d937ecf-d4b9-4902-b0ba-ad691e53b637  30-39    No 2020-04-24 18:37:10.306
# 2   988e4af0-fcea-4236-bbac-1c07b8bf03f5  20-29    No 2020-04-24 20:34:40.910
# 3   f42194ad-09f6-4bf6-892a-76f9bf7cde36  20-29    No 2020-04-25 14:19:05.085
# 4   16011f7f-f28e-442d-95c5-d5b5d88ab594  60-69    No 2020-04-26 10:53:15.817
# 5   9c82c3d8-83a2-43e2-a552-30e57b378d4d  30-39    No 2020-04-27 11:44:58.621
# 6   4847b8a8-66de-469d-a8e9-141a5bfe343d  20-29   Yes 2020-04-27 20:47:59.174
# 7   8553b697-0699-4f1d-b9c0-514e3b765304  40-49    No 2020-04-28 19:45:04.498
# 8   4776798e-b89b-435f-8287-b82ef3a7e7e4  30-39    No 2020-05-08 19:33:40.776
# 9   a83de1c1-da4f-4623-a517-62415a234ce3  30-39    No 2020-05-08 19:35:33.334
# 10  c3256cfe-004e-4d84-960d-8a8e5d886472  30-39    No 2020-05-08 19:37:57.297
# ...

# %%
df_English
# Out:
#                                     _id    age cough                datetime  \
# 0  81b2beff-5322-4fd4-b44b-2aea61930188  40-49    No 2020-04-21 17:38:32.572
# 1  7dbfd033-613d-4588-8c5d-7dfe302ce8bc  30-39    No 2020-04-22 08:19:29.529
# 2  42a5ef4b-6d54-4ddd-a187-78412b8b6bf4  40-49    No 2020-04-22 20:29:29.727
# 3  ffad31fb-fee8-49e7-95ff-23637a99f102  20-29    No 2020-04-22 22:26:44.961
# 4  8aed5f39-569d-4560-9491-73732a27dbac  20-29    No 2020-04-23 10:38:56.646
#
#   diagnosed fever  gender positive  \
# 0    [None]    No    Male       No
# 1    [None]    No  Female       No
# 2    [None]    No  Female       No
# 3  [Asthma]    No  Female       No
# 4    [None]    No    Male       No
#
#                                          recordCough  \
# 0  [81b2beff-5322-4fd4-b44b-2aea61930188_20200421...
# 1  [7dbfd033-613d-4588-8c5d-7dfe302ce8bc_20200422...
# 2                                                 []
# 3  [ffad31fb-fee8-49e7-95ff-23637a99f102_20200423...
# ...

# %%
df_Italian
# Out:
#                                     _id    age cough                datetime  \
# 0  b905d699-ea9e-495e-8284-c008eadb0285  40-49    No 2020-04-22 11:17:43.467
# 1  93cff82b-c8ea-4f06-980d-8cc678ebc000  50-59    No 2020-04-22 12:49:06.992
# 2  9dcd53fc-2bec-48a7-9053-40c7e7ebe18a  60-69    No 2020-04-22 13:05:53.784
# 3  40303ccb-ad4c-4e12-813d-0ca6c41d25b1  30-39    No 2020-04-23 06:10:41.349
# 4  6ba80f85-5382-43ee-9321-0e4283874c38  20-29    No 2020-04-23 13:02:04.050
#
#    diagnosed fever gender positive  \
# 0     [Asma]    No   Uomo       No
# 1  [Nessuna]    No  Donna       No
# 2  [Nessuna]    No  Donna       No
# 3     [Asma]    No  Donna       No
# 4  [Nessuna]    No  Donna       No
#
#                                          recordCough  \
# 0  [b905d699-ea9e-495e-8284-c008eadb0285_20200422...
# 1                                                 []
# 2  [9dcd53fc-2bec-48a7-9053-40c7e7ebe18a_20200422...
# 3                                                 []
# ...

# %%
df_it
# Out:
#                                      _id    age cough                datetime  \
# 0   e2112c7d-568c-41a5-8f22-b9a6d0d5e354  50-59    No 2020-04-24 21:18:22.062
# 1   2a3a540e-18d3-4cfc-b68d-a2fdf149452f  30-39    No 2020-04-24 21:38:42.624
# 2   1aeb6600-4ff3-4035-a658-31a3752ce526  40-49    No 2020-04-25 07:04:41.040
# 3   7e37494b-819c-4635-82ce-a8677c72e918  20-29    No 2020-04-26 11:17:51.807
# 4   5e56feaf-508e-481e-b9f6-c8c960627c12  40-49    No 2020-04-27 11:05:26.635
# 5   e5c0f026-8477-4ceb-812e-433852d426c0  30-39    No 2020-04-27 21:58:29.617
# 6   609f11aa-4d65-48d9-9627-1388e03602a4  40-49    No 2020-05-11 16:09:57.689
# 7   f5e2d15d-a978-42f3-8ee4-34c88fdc1754  20-29    No 2020-05-11 16:43:50.472
# 8   64663578-995e-4dd7-b10f-3d7a47a466ac  20-29    No 2020-05-11 16:52:04.056
# 9   5868caed-dbb0-41cd-9c61-5489e0cdb82c  10-19    No 2020-05-11 16:57:52.350
# 10  dbfde640-fac2-417f-b3c3-42d0fc09de43  10-19    No 2020-05-11 17:01:39.592
# ...

# %%
df_French
# Out:
#                                     _id    age cough                datetime  \
# 0  b7297eb4-a995-4bf5-937f-b80a15e8ec09    NaN   NaN 2020-04-21 18:53:05.730
# 1  dd5a074c-a389-4cae-b798-2b041330aa74  30-39   Oui 2020-04-22 21:34:46.242
# 2  2d95dead-8684-4e9f-89da-09c6fa5906a6  60-69   Non 2020-04-23 11:13:28.695
#
#   diagnosed fever     gender positive  \
# 0       NaN   NaN        NaN      NaN
# 1  [Aucune]   Non   Un homme      Non
# 2  [Aucune]   Non  Une femme      Non
#
#                                          recordCough  \
# 0                                                 []
# 1  [dd5a074c-a389-4cae-b798-2b041330aa74_20200422...
# 2                                                 []
#
#                                          recordVoice smoke  \
# 0  [b7297eb4-a995-4bf5-937f-b80a15e8ec09_20200421...   NaN
# 1  [dd5a074c-a389-4cae-b798-2b041330aa74_20200422...   Non
# 2                                                 []   Non
#
# ...

# %%
df_fr
# Out:
#                                     _id    age cough                datetime  \
# 0  7bf65a61-49ec-4e8a-b3d4-8d9157f24d6c  50-59   Oui 2020-04-24 15:56:54.832
# 1  200b699a-dcaa-4f15-afdf-14568827acb9  70-79   Non 2020-04-24 16:06:36.635
# 2  de21e01c-0628-4a45-a0af-5668364ed85c  60-69   Non 2020-04-24 18:25:26.147
# 3  2ae3b386-35c4-45c0-83f2-c6effe1c076b  30-39   Non 2020-04-25 13:40:36.769
# 4  e5faf9f4-3627-40bd-8538-64848322af86  30-39   Non 2020-04-27 07:02:58.897
# 5  1e556d6c-be53-48e0-8eb1-be5528610377  20-29   Non 2020-04-27 10:39:57.590
#
#   diagnosed fever     gender positive  \
# 0  [Aucune]   Non  Une femme      Non
# 1   [Autre]   Non   Un homme      Non
# 2  [Aucune]   Non  Une femme      Non
# 3  [Aucune]   Non  Une femme      Non
# 4  [Asthme]   Non   Un homme      Non
# 5  [Aucune]   Non   Un homme      Non
#
#                                          recordCough  \
# 0  [7bf65a61-49ec-4e8a-b3d4-8d9157f24d6c_20200424...
# ...

# %%
df_zh
# Out:
#                                     _id age cough                datetime  \
# 0  b49d1df0-b6c5-4509-b3e3-288732f58adc           2020-04-24 16:39:15.386
#
#   diagnosed fever gender positive recordCough recordVoice smoke symptoms
# 0        []                                []          []             []

# %%
df_SimplifiedChinese
# Out:
#                                     _id    age cough                datetime  \
# 0  2aeae190-14fe-4a24-826d-cd897dbc02ff  20-29       2020-04-22 09:15:40.139
# 1  1728a50c-8295-4601-be44-15bb676679de  20-29    没有 2020-04-23 09:21:28.327
#
#   diagnosed fever gender positive  \
# 0        []            男    没有检测过
# 1       [无]    没有      男    没有检测过
#
#                                          recordCough  \
# 0  [2aeae190-14fe-4a24-826d-cd897dbc02ff_20200422...
# 1  [1728a50c-8295-4601-be44-15bb676679de_20200423...
#
#                                          recordVoice smoke symptoms
# 0                                                 []             []
# 1  [1728a50c-8295-4601-be44-15bb676679de_20200423...   不抽烟  [无以上症状]
